# %%
import numpy as np
data = np.load('TD3_DeterministicTrack-v0_2.npy')

# %%
data
# Out:
# array([ -871.1607903 ,  -871.1607903 ,  -871.1607903 ,  -871.1607903 ,
#         -871.1607903 ,  -871.1607903 ,  -871.1607903 ,  -871.1607903 ,
#         -871.1607903 ,  -871.1607903 ,  -871.1607903 ,  -871.1607903 ,
#         -871.1607903 ,  -871.1607903 ,  -871.1607903 ,  -871.1607903 ,
#         -871.1607903 ,  -871.1607903 ,  -871.1607903 ,  -871.1607903 ,
#         -871.1607903 ,  -871.1607903 ,  -871.1607903 ,  -871.1607903 ,
#         -871.1607903 ,  -871.1607903 , -1716.20114833, -1786.96281806,
#        -1665.1415473 , -1561.17334387, -1634.74149267,  -983.09020238,
#         -884.50459022,  -687.55412063,  -702.40409621,  -621.87326823,
#         -583.1511964 ,  -405.1434251 ,  -336.83642108,  -268.39653911,
#         -363.84198219,  -423.88189953,  -588.56413092,  -602.51304372,
#         -323.32926734,  -282.27332098,  -345.86034226,  -319.64138267,
#         -350.54172638,  -338.45846748,  -334.96600486,  -326.90247066,
# ...

# %%
len(data)
# Out:
# 101

# %%
a = 5
b = 6
print('%d:%d'%(a,b))
# Out:
# 5:6
